# %% [markdown]
# - Objetivo: Apoiar um professor do SESI e um  orquestrador de IA para escolher os melhores estilos musicais para aplicar em atividades em sala de aula;
# - Público alvo: Pré adolescentes de 13 a 15 anos;
# --- Boxplot
# --- Suno

# %% [markdown]
# -----Tarefa 1:
# Exportar a planilha como CSV
#
# https://dontpad.com/pesquisamusical
#
# {#link da planilha#}
# https://docs.google.com/spreadsheets/d/1RFcHdzoyqB6jat7o7bAA5XjvLql5j11FVfHk4FQtKVg/edit?usp=sharing
# {#tarefas#}

# %% [markdown]
# -----# Tarefa 2:
# - Importar o .CSV no pandas

# %%
import pandas as pd

# %%
dados_Sesi = pd.read_csv('datasets/pesquisa_musical.csv')

# %% [markdown]
# ------ # Tarefa 3:
# - Remover a primeira ooluna e renomear

# %%
dados_Sesi.columns =['data_hora','rock','hiphop','mpb','reggae','funk','sertanejo','gospel','eletronica']

# %%
df_dadossesi = dados_Sesi.drop(columns=['data_hora'])

# %%
df_dadossesi
# Out:
#     rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0      3       1    1       1     1          1       1           3
# 1      5       3    5       2     1          3       1           5
# 2      1       5    1       1     1          1       1           5
# 3      1       5    4       4     4          1       1           5
# 4      5       4    3       4     1          1       2           5
# 5      5       2    2       2     1          1       2           4
# 6      2       4    4       1     4          4       1           3
# 7      5       3    3       3     1          2       3           4
# 8      4       4    4       1     4          4       1           4
# 9      5       5    1       3     4          1       1           3
# 10     3       2    5       4     3          4       4           2
# 11     4       1    5       1     1          2       5           1
# 12     5       1    3       1     1          1       1           4
# ...

# %%
df_dadossesi.head(10)
# Out:
#    rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0     3       1    1       1     1          1       1           3
# 1     5       3    5       2     1          3       1           5
# 2     1       5    1       1     1          1       1           5
# 3     1       5    4       4     4          1       1           5
# 4     5       4    3       4     1          1       2           5
# 5     5       2    2       2     1          1       2           4
# 6     2       4    4       1     4          4       1           3
# 7     5       3    3       3     1          2       3           4
# 8     4       4    4       1     4          4       1           4
# 9     5       5    1       3     4          1       1           3

# %% [markdown]
# ------ # Tarefa 4:
# Escolher um Gráfico que possa mostrar para o professor e orquestrador da IA quais os estilos tiveram nota menor e maior.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - Visualizando o gosto musical de acordo o estilo

# %%
df_dadossesi.value_counts
# Out:
# <bound method DataFrame.value_counts of     rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0      3       1    1       1     1          1       1           3
# 1      5       3    5       2     1          3       1           5
# 2      1       5    1       1     1          1       1           5
# 3      1       5    4       4     4          1       1           5
# 4      5       4    3       4     1          1       2           5
# 5      5       2    2       2     1          1       2           4
# 6      2       4    4       1     4          4       1           3
# 7      5       3    3       3     1          2       3           4
# 8      4       4    4       1     4          4       1           4
# 9      5       5    1       3     4          1       1           3
# 10     3       2    5       4     3          4       4           2
# 11     4       1    5       1     1          2       5           1
# ...

# %%
# calculando a média de valores
totals = df_dadossesi.mean()

# %%
# Criando o gráfico de barras
plt.figure(figsize=(10, 6))
totals.plot(kind='barh', color=['purple'])
# Out:
# <Axes: >

# %% [markdown]
# ----- # Tarefa 5
# faça um bloxpot e histograma que identifique a mediana, outliers e conte uma história

# %%
df_dadossesi.describe()
# Out:
#             rock     hiphop        mpb     reggae       funk  sertanejo  \
# count  37.000000  37.000000  37.000000  37.000000  37.000000  37.000000
# mean    3.675676   3.216216   3.432432   2.378378   1.972973   2.513514
# std     1.415275   1.583511   1.344547   1.421098   1.404091   1.346221
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     3.000000   2.000000   3.000000   1.000000   1.000000   1.000000
# 50%     4.000000   4.000000   4.000000   2.000000   1.000000   3.000000
# 75%     5.000000   5.000000   4.000000   3.000000   3.000000   3.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#           gospel  eletronica
# count  37.000000   37.000000
# mean    2.702703    3.297297
# std     1.578763    1.596261
# min     1.000000    1.000000
# 25%     1.000000    2.000000
# 50%     2.000000    4.000000
# 75%     4.000000    5.000000
# max     5.000000    5.000000

# %%
import seaborn as sns

# %%
#Criando variável
notas = df_dadossesi

# %%
#Mostrando o cabeçalho
notas.head()
# Out:
#    rock  hiphop  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0     3       1    1       1     1          1       1           3
# 1     5       3    5       2     1          3       1           5
# 2     1       5    1       1     1          1       1           5
# 3     1       5    4       4     4          1       1           5
# 4     5       4    3       4     1          1       2           5

# %%
sns.histplot(notas,kde=True,bins=10)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Perguntar a idade no DataSet de amanhã.
